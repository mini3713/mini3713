# %% [markdown]
# <a href="https://colab.research.google.com/github/mini3713/mini3713/blob/main/occupancy/clustering_by_age.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_excel("/content/Time use survey_Korea_2019_onehot.xlsx")
data
# Out:
#        Unnamed: 0  회차  가구일련번호  가구원일련번호  요일코드  평토일구분코드  성별코드  연령  연령코드  \
# 0               0   5      31        1     0        3     2  41     4
# 1               1   5      31        1     1        1     2  41     4
# 2               2   5      31        2     0        3     1  40     4
# 3               3   5      31        2     1        1     1  40     4
# 4               4   5      32        1     4        1     2  25     2
# ...           ...  ..     ...      ...   ...      ...   ...  ..   ...
# 52177       52177   7   12387        1     3        1     1  57     5
# 52178       52178   7   12387        2     2        1     2  56     5
# 52179       52179   7   12387        2     3        1     2  56     5
# 52180       52180   7   12388        1     0        3     1  61     6
# 52181       52181   7   12388        1     6        2     1  61     6
#
#       주택종류기타내용  ...  (주행동시간대) 오후 10:20  (주행동시간대) 오후 10:30  (주행동시간대) 오후 10:40  \
# ...

# %%
data1 = data.drop(['Unnamed: 0'], axis=1)
data1
# Out:
#        회차  가구일련번호  가구원일련번호  요일코드  평토일구분코드  성별코드  연령  연령코드 주택종류기타내용  주택면적  ...  \
# 0       5      31        1     0        3     2  41     4      NaN  56.0  ...
# 1       5      31        1     1        1     2  41     4      NaN  56.0  ...
# 2       5      31        2     0        3     1  40     4      NaN   NaN  ...
# 3       5      31        2     1        1     1  40     4      NaN   NaN  ...
# 4       5      32        1     4        1     2  25     2      NaN  56.0  ...
# ...    ..     ...      ...   ...      ...   ...  ..   ...      ...   ...  ...
# 52177   7   12387        1     3        1     1  57     5      NaN  66.0  ...
# 52178   7   12387        2     2        1     2  56     5      NaN   NaN  ...
# 52179   7   12387        2     3        1     2  56     5      NaN   NaN  ...
# 52180   7   12388        1     0        3     1  61     6      NaN  99.0  ...
# 52181   7   12388        1     6        2     1  61     6      NaN  99.0  ...
#
# ...

# %%
data_f = data1.iloc[:,:12]
data_f
# Out:
#        회차  가구일련번호  가구원일련번호  요일코드  평토일구분코드  성별코드  연령  연령코드 주택종류기타내용  주택면적  \
# 0       5      31        1     0        3     2  41     4      NaN  56.0
# 1       5      31        1     1        1     2  41     4      NaN  56.0
# 2       5      31        2     0        3     1  40     4      NaN   NaN
# 3       5      31        2     1        1     1  40     4      NaN   NaN
# 4       5      32        1     4        1     2  25     2      NaN  56.0
# ...    ..     ...      ...   ...      ...   ...  ..   ...      ...   ...
# 52177   7   12387        1     3        1     1  57     5      NaN  66.0
# 52178   7   12387        2     2        1     2  56     5      NaN   NaN
# 52179   7   12387        2     3        1     2  56     5      NaN   NaN
# 52180   7   12388        1     0        3     1  61     6      NaN  99.0
# 52181   7   12388        1     6        2     1  61     6      NaN  99.0
#
#        가구총소득구간코드  휴일종류코드
# 0            4.0     NaN
# 1            4.0     NaN
# ...

# %%
data_t = data1.iloc[:,12:]
data_t
# Out:
#        (주행동시간대) 오전 00:00  (주행동시간대) 오전 00:10  (주행동시간대) 오전 00:20  \
# 0                      1                  1                  1
# 1                      1                  1                  1
# 2                      1                  1                  1
# 3                      1                  1                  1
# 4                      1                  1                  1
# ...                  ...                ...                ...
# 52177                  1                  1                  1
# 52178                  1                  1                  1
# 52179                  1                  1                  1
# 52180                  1                  1                  1
# 52181                  1                  1                  1
#
#        (주행동시간대) 오전 00:30  (주행동시간대) 오전 00:40  (주행동시간대) 오전 00:50  \
# 0                      1                  1                  1
# 1                      1                  1                  1
# ...

# %%
total = pd.concat([data_f, data_t], axis=1)
total
# Out:
#        회차  가구일련번호  가구원일련번호  요일코드  평토일구분코드  성별코드  연령  연령코드 주택종류기타내용  주택면적  ...  \
# 0       5      31        1     0        3     2  41     4      NaN  56.0  ...
# 1       5      31        1     1        1     2  41     4      NaN  56.0  ...
# 2       5      31        2     0        3     1  40     4      NaN   NaN  ...
# 3       5      31        2     1        1     1  40     4      NaN   NaN  ...
# 4       5      32        1     4        1     2  25     2      NaN  56.0  ...
# ...    ..     ...      ...   ...      ...   ...  ..   ...      ...   ...  ...
# 52177   7   12387        1     3        1     1  57     5      NaN  66.0  ...
# 52178   7   12387        2     2        1     2  56     5      NaN   NaN  ...
# 52179   7   12387        2     3        1     2  56     5      NaN   NaN  ...
# 52180   7   12388        1     0        3     1  61     6      NaN  99.0  ...
# 52181   7   12388        1     6        2     1  61     6      NaN  99.0  ...
#
# ...

# %%
total_a = total.iloc[:,7]
age = pd.concat([total_a, data_t], axis=1)
age
# Out:
#        연령코드  (주행동시간대) 오전 00:00  (주행동시간대) 오전 00:10  (주행동시간대) 오전 00:20  \
# 0         4                  1                  1                  1
# 1         4                  1                  1                  1
# 2         4                  1                  1                  1
# 3         4                  1                  1                  1
# 4         2                  1                  1                  1
# ...     ...                ...                ...                ...
# 52177     5                  1                  1                  1
# 52178     5                  1                  1                  1
# 52179     5                  1                  1                  1
# 52180     6                  1                  1                  1
# 52181     6                  1                  1                  1
#
#        (주행동시간대) 오전 00:30  (주행동시간대) 오전 00:40  (주행동시간대) 오전 00:50  \
# 0                      1                  1                  1
# ...

# %%
# !pip install tslearn
from tslearn.clustering import TimeSeriesKMeans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 875 kB 5.1 MB/s
# ...

# %%
age1 = age[age['연령코드'] == 1]
age1 = age1.drop(['연령코드'], axis=1)
# Out:
#        (주행동시간대) 오전 00:00  (주행동시간대) 오전 00:10  (주행동시간대) 오전 00:20  \
# 14                     1                  1                  1
# 15                     1                  1                  1
# 16                     1                  1                  1
# 17                     1                  1                  1
# 42                     1                  1                  1
# ...                  ...                ...                ...
# 52167                  1                  1                  1
# 52168                  1                  1                  1
# 52169                  1                  1                  1
# 52170                  1                  1                  1
# 52171                  1                  1                  1
#
#        (주행동시간대) 오전 00:30  (주행동시간대) 오전 00:40  (주행동시간대) 오전 00:50  \
# 14                     1                  1                  1
# 15                     1                  1                  1
# ...

# %%
print(len(age1))
# Out:
# 5662

# %%
age2 = age[age['연령코드'] == 2]
age2 = age2.drop(['연령코드'], axis=1)

age3 = age[age['연령코드'] == 3]
age3 = age3.drop(['연령코드'], axis=1)

age4 = age[age['연령코드'] == 4]
age4 = age4.drop(['연령코드'], axis=1)

age5 = age[age['연령코드'] == 5]
age5 = age5.drop(['연령코드'], axis=1)

age6 = age[age['연령코드'] == 6]
age6 = age6.drop(['연령코드'], axis=1)

print(len(age2))
print(len(age3))
print(len(age4))
print(len(age5))
print(len(age6))
# Out:
# 5688
# 7000
# 8814
# 9102
# 15916

# %%
age1_sum = age1.sum(axis=0)
age1_rate = age1_sum / 5662

age2_sum = age2.sum(axis=0)
age2_rate = age2_sum / 5688

age3_sum = age3.sum(axis=0)
age3_rate = age3_sum / 7000

age4_sum = age4.sum(axis=0)
age4_rate = age4_sum / 8814

age5_sum = age5.sum(axis=0)
age5_rate = age5_sum / 9102

age6_sum = age6.sum(axis=0)
age6_rate = age6_sum / 15916

ts = pd.date_range('2019-09-01 00:00:00', '2019-09-01 23:50:00', freq='10min')
plt.figure(figsize=(18,4))
plt.plot(ts, age1_rate)
plt.plot(ts, age2_rate)
plt.plot(ts, age3_rate)
plt.plot(ts, age4_rate)
plt.plot(ts, age5_rate)
plt.plot(ts, age6_rate)
plt.legend(labels=['1','2','3','4','5','6'])

plt.show()

# %%
total_f = total.iloc[:,4]
age = pd.concat([total_f, total_a, data_t], axis=1)

# %%
age1 = age[age['연령코드'] == 1]

# %%
age1_wd = age1[age1['평토일구분코드'] == 1]
age1_we = age1[(age1['평토일구분코드'] == 2) | (age1['평토일구분코드'] == 3)]

age1_wd = age1_wd.drop(['평토일구분코드','연령코드'], axis=1)
age1_we = age1_we.drop(['평토일구분코드','연령코드'], axis=1)

# %%
print(len(age1_wd))
print(len(age1_we))
# Out:
# 3376
# 2286

# %%
age1_wd_sum = age1_wd.sum(axis=0)
age1_wd_rate = age1_wd_sum / 3376

age1_we_sum = age1_we.sum(axis=0)
age1_we_rate = age1_we_sum / 2286

ts = pd.date_range('2019-09-01 00:00:00', '2019-09-01 23:50:00', freq='10min')
plt.figure(figsize=(18,4))

plt.plot(ts, age1_wd_rate)
plt.plot(ts, age1_we_rate)

plt.legend(labels=['wd','we'])

plt.show()

# %%
age2 = age[age['연령코드'] == 2]

age2_wd = age2[age2['평토일구분코드'] == 1]
age2_we = age2[(age2['평토일구분코드'] == 2) | (age2['평토일구분코드'] == 3)]

age2_wd = age2_wd.drop(['평토일구분코드','연령코드'], axis=1)
age2_we = age2_we.drop(['평토일구분코드','연령코드'], axis=1)

print(len(age2_wd))
print(len(age2_we))
# Out:
# 3413
# 2275

# %%
age2_wd_sum = age2_wd.sum(axis=0)
age2_wd_rate = age2_wd_sum / 3413

age2_we_sum = age2_we.sum(axis=0)
age2_we_rate = age2_we_sum / 2275

ts = pd.date_range('2019-09-01 00:00:00', '2019-09-01 23:50:00', freq='10min')
plt.figure(figsize=(18,4))

plt.plot(ts, age2_wd_rate)
plt.plot(ts, age2_we_rate)

plt.legend(labels=['wd','we'])

plt.show()

# %%
age3 = age[age['연령코드'] == 3]

age3_wd = age3[age3['평토일구분코드'] == 1]
age3_we = age3[(age3['평토일구분코드'] == 2) | (age3['평토일구분코드'] == 3)]

age3_wd = age3_wd.drop(['평토일구분코드','연령코드'], axis=1)
age3_we = age3_we.drop(['평토일구분코드','연령코드'], axis=1)

print(len(age3_wd))
print(len(age3_we))
# Out:
# 4223
# 2777

# %%
age3_wd_sum = age3_wd.sum(axis=0)
age3_wd_rate = age3_wd_sum / 4223

age3_we_sum = age3_we.sum(axis=0)
age3_we_rate = age3_we_sum / 2777

ts = pd.date_range('2019-09-01 00:00:00', '2019-09-01 23:50:00', freq='10min')
plt.figure(figsize=(18,4))

plt.plot(ts, age3_wd_rate)
plt.plot(ts, age3_we_rate)

plt.legend(labels=['wd','we'])

plt.show()

# %%
age4 = age[age['연령코드'] == 4]

age4_wd = age4[age4['평토일구분코드'] == 1]
age4_we = age4[(age4['평토일구분코드'] == 2) | (age4['평토일구분코드'] == 3)]

age4_wd = age4_wd.drop(['평토일구분코드','연령코드'], axis=1)
age4_we = age4_we.drop(['평토일구분코드','연령코드'], axis=1)

print(len(age4_wd))
print(len(age4_we))
# Out:
# 5196
# 3618

# %%
age4_wd_sum = age4_wd.sum(axis=0)
age4_wd_rate = age4_wd_sum / 5196

age4_we_sum = age4_we.sum(axis=0)
age4_we_rate = age4_we_sum / 3618

ts = pd.date_range('2019-09-01 00:00:00', '2019-09-01 23:50:00', freq='10min')
plt.figure(figsize=(18,4))

plt.plot(ts, age4_wd_rate)
plt.plot(ts, age4_we_rate)

plt.legend(labels=['wd','we'])

plt.show()

# %%
age5 = age[age['연령코드'] == 5]

age5_wd = age5[age5['평토일구분코드'] == 1]
age5_we = age5[(age5['평토일구분코드'] == 2) | (age5['평토일구분코드'] == 3)]

age5_wd = age5_wd.drop(['평토일구분코드','연령코드'], axis=1)
age5_we = age5_we.drop(['평토일구분코드','연령코드'], axis=1)

print(len(age5_wd))
print(len(age5_we))
# Out:
# 5489
# 3613

# %%
age5_wd_sum = age5_wd.sum(axis=0)
age5_wd_rate = age5_wd_sum / 5489

age5_we_sum = age5_we.sum(axis=0)
age5_we_rate = age5_we_sum / 3613

ts = pd.date_range('2019-09-01 00:00:00', '2019-09-01 23:50:00', freq='10min')
plt.figure(figsize=(18,4))

plt.plot(ts, age5_wd_rate)
plt.plot(ts, age5_we_rate)

plt.legend(labels=['wd','we'])

plt.show()

# %%
age6 = age[age['연령코드'] == 6]

age6_wd = age6[age6['평토일구분코드'] == 1]
age6_we = age6[(age6['평토일구분코드'] == 2) | (age6['평토일구분코드'] == 3)]

age6_wd = age6_wd.drop(['평토일구분코드','연령코드'], axis=1)
age6_we = age6_we.drop(['평토일구분코드','연령코드'], axis=1)

print(len(age6_wd))
print(len(age6_we))
# Out:
# 9604
# 6312

# %%
age6_wd_sum = age6_wd.sum(axis=0)
age6_wd_rate = age6_wd_sum / 9604

age6_we_sum = age6_we.sum(axis=0)
age6_we_rate = age6_we_sum / 6312

ts = pd.date_range('2019-09-01 00:00:00', '2019-09-01 23:50:00', freq='10min')
plt.figure(figsize=(18,4))

plt.plot(ts, age6_wd_rate)
plt.plot(ts, age6_we_rate)

plt.legend(labels=['wd','we'])

plt.show()
