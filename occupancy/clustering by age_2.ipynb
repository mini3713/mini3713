# %% [markdown]
# <a href="https://colab.research.google.com/github/mini3713/mini3713/blob/main/occupancy/clustering%20by%20age_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Time use survey_Korea_2019_onehot_only.xlsx')

# %%
df_c = pd.read_csv('/content/2019_시간대_전체_20221223_31968.csv', encoding = 'cp949')

# %%
df_oh = df.drop(df.columns[[0]], axis=1)
df_oh
# Out:
#        (주행동시간대) 오전 00:00  (주행동시간대) 오전 00:10  (주행동시간대) 오전 00:20  \
# 0                      1                  1                  1
# 1                      1                  1                  1
# 2                      1                  1                  1
# 3                      1                  1                  1
# 4                      1                  1                  1
# ...                  ...                ...                ...
# 52177                  1                  1                  1
# 52178                  1                  1                  1
# 52179                  1                  1                  1
# 52180                  1                  1                  1
# 52181                  1                  1                  1
#
#        (주행동시간대) 오전 00:30  (주행동시간대) 오전 00:40  (주행동시간대) 오전 00:50  \
# 0                      1                  1                  1
# 1                      1                  1                  1
# ...

# %%
total = pd.concat([df_c, df_oh], axis=1)

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52182 entries, 0 to 52181
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   요일코드      52182 non-null  int64
#  1   평토일구분코드   52182 non-null  int64
#  2   연령        52182 non-null  int64
#  3   연령코드      52182 non-null  int64
#  4   경제활동상태코드  49206 non-null  float64
#  5   휴일종류코드    29654 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 2.4 MB

# %%
df_c_temp = df_c[df_c.경제활동상태코드.isnull()]
df_c_temp
# Out:
#        요일코드  평토일구분코드  연령  연령코드  경제활동상태코드  휴일종류코드
# 0         0        3  10     1       NaN     NaN
# 1         0        3  10     1       NaN     NaN
# 2         0        3  10     1       NaN     NaN
# 3         0        3  10     1       NaN     NaN
# 4         0        3  10     1       NaN     NaN
# ...     ...      ...  ..   ...       ...     ...
# 42323     6        2  14     1       NaN     NaN
# 42324     6        2  14     1       NaN     NaN
# 42325     6        2  14     1       NaN     NaN
# 42326     6        2  14     1       NaN     NaN
# 42327     6        2  14     1       NaN     NaN
#
# [2976 rows x 6 columns]

# %%
df_c_temp = df_c_temp.drop(['휴일종류코드'], axis=1)
df_c_temp
# Out:
#        요일코드  평토일구분코드  연령  연령코드  경제활동상태코드
# 0         0        3  10     1       NaN
# 1         0        3  10     1       NaN
# 2         0        3  10     1       NaN
# 3         0        3  10     1       NaN
# 4         0        3  10     1       NaN
# ...     ...      ...  ..   ...       ...
# 42323     6        2  14     1       NaN
# 42324     6        2  14     1       NaN
# 42325     6        2  14     1       NaN
# 42326     6        2  14     1       NaN
# 42327     6        2  14     1       NaN
#
# [2976 rows x 5 columns]

# %%
for idx in df_c_temp.index:

  if df_c_temp.loc[idx,'연령코드'] == 1 : 

    df_c_temp.loc[idx,'경제활동상태코드'] = 3

# %%
df_c_temp
# Out:
#        요일코드  평토일구분코드  연령  연령코드  경제활동상태코드
# 0         0        3  10     1       3.0
# 1         0        3  10     1       3.0
# 2         0        3  10     1       3.0
# 3         0        3  10     1       3.0
# 4         0        3  10     1       3.0
# ...     ...      ...  ..   ...       ...
# 42323     6        2  14     1       3.0
# 42324     6        2  14     1       3.0
# 42325     6        2  14     1       3.0
# 42326     6        2  14     1       3.0
# 42327     6        2  14     1       3.0
#
# [2976 rows x 5 columns]

# %%
df_c_leave = df_c.dropna(subset=['경제활동상태코드'])

# %%
df_c_leave = df_c_leave.drop(['휴일종류코드'], axis=1)

# %%
df_c_leave
# Out:
#        요일코드  평토일구분코드  연령  연령코드  경제활동상태코드
# 604       0        3  15     1       1.0
# 605       0        3  15     1       3.0
# 606       0        3  15     1       3.0
# 607       0        3  15     1       3.0
# 608       0        3  15     1       3.0
# ...     ...      ...  ..   ...       ...
# 52177     6        2  93     6       3.0
# 52178     6        2  94     6       3.0
# 52179     6        2  95     6       3.0
# 52180     6        2  96     6       3.0
# 52181     6        2  97     6       3.0
#
# [49206 rows x 5 columns]

# %%
total = pd.concat([df_c_temp, df_c_leave])
total
# Out:
#        요일코드  평토일구분코드  연령  연령코드  경제활동상태코드
# 0         0        3  10     1       3.0
# 1         0        3  10     1       3.0
# 2         0        3  10     1       3.0
# 3         0        3  10     1       3.0
# 4         0        3  10     1       3.0
# ...     ...      ...  ..   ...       ...
# 52177     6        2  93     6       3.0
# 52178     6        2  94     6       3.0
# 52179     6        2  95     6       3.0
# 52180     6        2  96     6       3.0
# 52181     6        2  97     6       3.0
#
# [52182 rows x 5 columns]

# %%
data = pd.concat([total, df_oh], axis=1)
data
# Out:
#        요일코드  평토일구분코드  연령  연령코드  경제활동상태코드  (주행동시간대) 오전 00:00  \
# 0         0        3  10     1       3.0                  1
# 1         0        3  10     1       3.0                  1
# 2         0        3  10     1       3.0                  1
# 3         0        3  10     1       3.0                  1
# 4         0        3  10     1       3.0                  1
# ...     ...      ...  ..   ...       ...                ...
# 52177     6        2  93     6       3.0                  1
# 52178     6        2  94     6       3.0                  1
# 52179     6        2  95     6       3.0                  1
# 52180     6        2  96     6       3.0                  1
# 52181     6        2  97     6       3.0                  1
#
#        (주행동시간대) 오전 00:10  (주행동시간대) 오전 00:20  (주행동시간대) 오전 00:30  \
# 0                      1                  1                  1
# 1                      1                  1                  1
# ...

# %%
df_n = pd.read_csv('/content/2019_시간대_전체_20221223_21944.csv', encoding = 'cp949')
df_n
# Out:
#        회차
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
# ...    ..
# 52177   7
# 52178   7
# 52179   7
# 52180   7
# 52181   7
#
# [52182 rows x 1 columns]

# %%
data = pd.concat([df_n, data], axis=1)

# %% [markdown]
# ## **groupby**

# %%
df5_1_wd = data[(data['회차'] == 5)

# %%
# month:MAY
df5_1_wd = data[(data['회차'] == 5) & (data['평토일구분코드'] == 1) & (data['연령코드'] == 1)]
df5_1_we = data[(data['회차'] == 5) & (data['연령코드'] == 1) & ~(data['평토일구분코드'] == 1)]
df5_2_wd = data[(data['회차'] == 5) & (data['평토일구분코드'] == 1) & (data['연령코드'] == 2)]
df5_2_we = data[(data['회차'] == 5) & (data['연령코드'] == 2) & ~(data['평토일구분코드'] == 1)]
df5_3_wd = data[(data['회차'] == 5) & (data['평토일구분코드'] == 1) & (data['연령코드'] == 3)]
df5_3_we = data[(data['회차'] == 5) & (data['연령코드'] == 3) & ~(data['평토일구분코드'] == 1)]
df5_4_wd = data[(data['회차'] == 5) & (data['평토일구분코드'] == 1) & (data['연령코드'] == 4)]
df5_4_we = data[(data['회차'] == 5) & (data['연령코드'] == 4) & ~(data['평토일구분코드'] == 1)]
df5_5_wd = data[(data['회차'] == 5) & (data['평토일구분코드'] == 1) & (data['연령코드'] == 5)]
df5_5_we = data[(data['회차'] == 5) & (data['연령코드'] == 5) & ~(data['평토일구분코드'] == 1)]
df5_6_wd = data[(data['회차'] == 5) & (data['평토일구분코드'] == 1) & (data['연령코드'] == 6)]
df5_6_we = data[(data['회차'] == 5) & (data['연령코드'] == 6) & ~(data['평토일구분코드'] == 1)]

# %%
print(len(df5_1_wd.loc[df5_1_wd['연령코드'] == 1]))
print(len(df5_2_wd.loc[df5_2_wd['연령코드'] == 2]))
print(len(df5_3_wd.loc[df5_3_wd['연령코드'] == 3]))
print(len(df5_4_wd.loc[df5_4_wd['연령코드'] == 4]))
print(len(df5_5_wd.loc[df5_5_wd['연령코드'] == 5]))
print(len(df5_6_wd.loc[df5_6_wd['연령코드'] == 6]))
print(len(df5_1_we.loc[df5_1_we['연령코드'] == 1]))
print(len(df5_2_we.loc[df5_2_we['연령코드'] == 2]))
print(len(df5_3_we.loc[df5_3_we['연령코드'] == 3]))
print(len(df5_4_we.loc[df5_4_we['연령코드'] == 4]))
print(len(df5_5_we.loc[df5_5_we['연령코드'] == 5]))
print(len(df5_6_we.loc[df5_6_we['연령코드'] == 6]))
# Out:
# 547
# 582
# 675
# 872
# 934
# 1612
# 1152
# 1149
# 1368
# 1820
# 1840
# 3123

# %% [markdown]
# ## **Pattern**
